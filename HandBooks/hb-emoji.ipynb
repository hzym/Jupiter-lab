# %% [markdown]
# # git commit 的 emoji 使用指南
#
#
#
# | emoji                                   | emoji 代码                    | commit 说明                                                  |
# | :-------------------------------------- | :---------------------------- | :----------------------------------------------------------- |
# | :art: (调色板)                          | `:art:`                       | Improving structure / format of the code.<br />改进代码的结构 / 格式。 |
# | :zap: (闪电):racehorse: (赛马)          | `:zap:“:racehorse:`           | Improving performance.<br />提升性能                         |
# | :fire: (火焰)                           | `:fire:`                      | Removing code or files.<br />删除代码或文件                  |
# | :bug: (bug)                             | `:bug:`                       | Fixing a bug.<br />修复 bug                                  |
# | :ambulance: (急救车)                    | `:ambulance:`                 | Critical hotfix.<br />重要补丁                               |
# | :sparkles: (火花)                       | `:sparkles:`                  | Introducing new features.<br />引入新功能                    |
# | :memo: (备忘录)                         | `:memo:`                      | Writing docs.<br />撰写文档                                  |
# | :rocket: (火箭)                         | `:rocket:`                    | Deploying stuff.<br />部署功能                               |
# | :lipstick: (口红)                       | `:lipstick:`                  | Updating the UI and style files.<br />更新 UI 和样式文件     |
# | :tada: (庆祝)                           | `:tada:`                      | Initial commit.<br />初次提交                                |
# | :white_check_mark: (白色复选框)         | `:white_check_mark:`          | Updating tests.<br />增加测试                                |
# | :lock: (锁)                             | `:lock:`                      | Fixing security issues.<br />修复安全问题                    |
# | :apple: (苹果)                          | `:apple:`                     | Fixing something on macOS.<br />修复 macOS 下的问题          |
# | :penguin: (企鹅)                        | `:penguin:`                   | Fixing something on Linux.<br />修复 Linux 下的问题                       |
# | :checkered_flag: (旗帜)                 | `:checked_flag:`              | Fixing something on Windows.<br />修复 Windows 下的问题      |
# | :robot: (机器人)                        | `:robot:`                     | Fixing something on Android.<br />修复 Android 系统。        |
# | :green_apple: (绿苹果)                  | `:green_apple:`               | Fixing something on iOS.<br />修复 iOS 系统。                |
# | :bookmark: (书签)                       | `:bookmark:`                  | Releasing / Version tags.<br />发行/版本标签                 |
# | :rotating_light: (警车灯)               | `:rotating_light:`            | Removing linter warnings.<br />删除链接警告                  |
# | :construction: (施工)                   | `:construction:`              | Work in progress.<br />正在进行的工作                        |
# | :green_heart: (绿心)                    | `:green_heart:`               | Fixing CI Build.<br />修复 CI 构建问题                       |
# | :arrow_down: (下降箭头)                 | `:arrow_down:`                | Downgrading dependencies.<br />降级依赖                      |
# | :arrow_up: (上升箭头)                   | `:arrow_up:`                  | Upgrading dependencies.<br />升级依赖                        |
# | :pushpin: (​图钉)​                        | `:pushpin:`                   | Pinning dependencies to specific versions.<br />固定特定版本的依赖关系。 |
# | :construction_worker: (工人)            | `:construction_worker:`       | Adding CI build system.<br />增加 CI 构建系统                |
# | :chart_with_upwards_trend: (上升趋势图) | `:chart_with_upwards_trend:`  | Adding analytics or tracking code.<br />添加分析或跟踪代码   |
# | :recycle: (循环)                        | `:recycle:`                   | Refactoring code.<br />重构代码                              |
# | :hammer: (锤子)                         | `:hammer:`                    | 重大重构                                                     |
# | :whale: (鲸鱼)                          | `:whale:`                     | Work about Docker.<br />Docker 相关工作                      |
# | :heavy_plus_sign: (加号)                | `:heavy_plug_sign:`           | Adding a dependency.<br />增加一个依赖项                     |
# | :heavy_minus_sign: (减号)               | `:heavy_minus_sign:`          | Removing a dependency.<br />减少一个依赖项                   |
# | :wrench: (扳手)                         | `:wrench:`                    | Changing configuration files.<br />修改配置文件              |
# | :globe_with_meridians: (地球)           | `:globe_with_meridians:`      | Internationalization and localization.<br />国际化与本地化   |
# | :pencil2: (铅笔)                        | `:pencil2:`                   | Fixing typos.<br />修改错字                                  |
# | :poop:                                  | `:poop:`                      | Writing bad code that needs to be improved.<br />编写需要改进的糟糕代码。 |
# | :rewind:                                | `:rewind:`                    | Reverting changes.<br />恢复更改。                           |
# | :twisted_rightwards_arrows:             | `:twisted_rightwards_arrows:` | Merging branches.<br />合并分支。                            |
# | :package: (包裹)                        | `:package:`                   | Updating compiled files or packages.<br />更新已编译的文件或包。 |
# | :alien: (外星人)                        | `:alien:`                     | Updating code due to external API changes.<br />由于外部 API 更改而更新代码。 |
# | :truck: (卡车)​                          | `:truck:`                     | Moving or renaming files.<br />移动或重命名文件。            |
# | :page_facing_up: (许可证)               | `:page_facing_up:`            | Adding or updating license.<br />添加或更新许可证。          |
# | :boom:                                  | `:boom:`                      | Introducing breaking changes.<br />引入突破性变化。          |
# | :bento:                                 | `:bento:`                     | Adding or updating assets.<br />添加或更新资产。             |
# | :ok_hand:                               | `:ok_hand:`                   | Updating code due to code review changes.<br />由于代码审查更改而更新代码。 |
# | :wheelchair: (轮椅)                     | `:wheelchair:`                | Improving accessibility.<br />提高可访问性。                 |
# | :bulb: (灯泡)                           | `:bulb:`                      | Documenting source code.<br />记录源代码。                   |
# | :beers: (啤酒)                          | `:beers:`                     | Writing code drunkenly.<br />醉醺醺地写代码。                |
# | :speech_balloon:                        | `:speech_balloon:`            | Updating text and literals.<br />更新文本和文字。            |
# | :card_file_box: (文件盒)​                | `:card_file_box:`             | Performing database related changes.<br />执行与数据库相关的更改。 |
# | :loud_sound: (喇叭)​                     | `:loud_sound:`                | Adding logs.<br />添加 Logs。                                |
# | :mute: (禁音)​                           | `:mute:`                      | Removing logs.<br />删除 Logs。                              |
# | :busts_in_silhouette:                   | `:busts_in_silhouette:`       | Adding contributor(s).<br />增加贡献者。                     |
# | :children_crossing:                     | `:children_crossing`:         | Improving user experience / usability.<br />提高用户体验 / 可用性。 |
# | :building_construction:                 | `:building_construction:`     | Making architectural changes.<br />进行架构上的改变。        |
# | :iphone: (手机)​                         | `:iphone:`                    | Working on responsive design.<br />致力于响应式设计。        |
# | :clown_face: (小丑)​                     | `:clown_face:`                | Mocking things.<br />嘲笑的事情。                            |
# | :egg: ​(蛋)​                              | `:egg:`                       | Adding an easter egg.<br />添加一个复活节彩蛋。              |
# | :see_no_evil: ​(​猴子)​                    | `:see_no_evil:`               | Adding or updating a .gitignore file<br />添加或更新.gignore 文件 |
# | :camera_flash: ​(照相机)                 | `:camera_flash`:              | Adding or updating snapshots<br />添加或更新快照             |
# | :alembic:                               | `:alembic:`                   | Experimenting new things<br />尝试新事物                     |
# | :mag: ​(放大镜)                          | `:mag:`                       | Improving SEO<br />改进 SEO                                  |
# | :wheel_of_dharma:                       | `:wheel_of_dharma:`           | Work about Kubernetes<br />有关 Kubernetes 的工作            |
# | :label: ​(标签)                          | `:label:`                     | Adding or updating types (Flow, TypeScript)<br />添加或更新类型(流、打字稿) |
# | :seedling: ​(种子)                       | `:seedling:`                  | Adding or updating seed files<br />添加或更新种子文件        |
# | :triangular_flag_on_post: (三角旗帜)    | `:triangular_flag_on_post:`   | Adding, updating, or removing feature flags<br />添加、更新或删除功能标志 |
# | :goal_net:                              | `:goal_net:`                  | Catching errors<br />捕捉错误                                |
# | :dizzy:                                 | `:dizzy:`                     | Adding or updating animations and transitions<br />添加或更新动画和过渡 |
# | :wastebasket: (垃圾桶)                  | `:wastebasket:`               | Deprecating code that needs to be cleaned up.<br />需要清理的弃用代码。 |
